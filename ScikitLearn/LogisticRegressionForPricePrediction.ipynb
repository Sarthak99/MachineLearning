# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# 5            NEAR BAY
# 6            NEAR BAY
# 7            NEAR BAY
# 8            NEAR BAY
# 9            NEAR BAY
# 10           NEAR BAY
# 11           NEAR BAY
# 12           NEAR BAY
# 13           NEAR BAY
# 14           NEAR BAY
# 15           NEAR BAY
# 16           NEAR BAY
# 17           NEAR BAY
# 18           NEAR BAY
# 19           NEAR BAY
# 20           NEAR BAY
# 21           NEAR BAY
# 22           NEAR BAY
# 23           NEAR BAY
# 24           NEAR BAY
# 25           NEAR BAY
# 26           NEAR BAY
# 27           NEAR BAY
# 28           NEAR BAY
# 29           NEAR BAY
# ...               ...
# 20610          INLAND
# 20611          INLAND
# 20612          INLAND
# 20613          INLAND
# 20614          INLAND
# 20615          INLAND
# 20616          INLAND
# 20617          INLAND
# 20618          INLAND
# 20619          INLAND
# 20620          INLAND
# 20621          INLAND
# 20622          INLAND
# 20623          INLAND
# 20624          INLAND
# 20625          INLAND
# 20626          INLAND
# 20627          INLAND
# 20628          INLAND
# 20629          INLAND
# 20630          INLAND
# 20631          INLAND
# 20632          INLAND
# 20633          INLAND
# 20634          INLAND
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20433 rows x 10 columns]

# %%
housing_data = housing_data.dropna()

# %%
housing_data.shape
# Out:
# (20433, 10)

# %%
housing_data = housing_data.drop(housing_data.loc[housing_data["median_house_value"]==500001].index)

# %%
housing_data.shape
# Out:
# (19475, 10)

# %%
housing_data["median_house_value"].median()
# Out:
# 173800.0

# %%
housing_data["ocean_proximity"].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
housing_data =pd.get_dummies(housing_data, columns=["ocean_proximity"])

# %%
housing_data.sample(5)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20138    -119.05     34.40                50.0       1236.0           282.0
# 8366     -118.35     33.97                26.0       3832.0          1074.0
# 13103    -121.34     38.44                14.0       3205.0           465.0
# 10172    -117.98     33.86                25.0       1025.0           266.0
# 10388    -117.64     33.59                 4.0       3274.0           383.0
#
#        population  households  median_income  median_house_value  \
# 20138      1079.0       257.0         2.6991            181300.0
# 8366       2340.0       904.0         2.6734            143400.0
# 13103      1439.0       456.0         5.7452            240900.0
# 10172       726.0       183.0         3.8750            137500.0
# 10388      1312.0       390.0         8.1611            348000.0
#
#        ocean_proximity_<1H OCEAN  ocean_proximity_INLAND  \
# 20138                          1                       0
# 8366                           1                       0
# 13103                          0                       1
# 10172                          1                       0
# 10388                          1                       0
#
#        ocean_proximity_ISLAND  ocean_proximity_NEAR BAY  \
# 20138                       0                         0
# 8366                        0                         0
# 13103                       0                         0
# 10172                       0                         0
# 10388                       0                         0
#
#        ocean_proximity_NEAR OCEAN
# 20138                           0
# 8366                            0
# 13103                           0
# 10172                           0
# 10388                           0

# %%
median = housing_data["median_house_value"].median()
median
# Out:
# 173800.0

# %%
housing_data["above_median"] = (housing_data["median_house_value"] - median)>0

# %%
housing_data.sample(5)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11778    -121.29     38.76                12.0       1198.0           174.0
# 18856    -122.27     41.23                40.0       1958.0           386.0
# 20018    -119.04     36.09                15.0       2288.0           401.0
# 17657    -121.89     37.28                35.0       2418.0           375.0
# 10408    -117.58     33.65                 4.0       2000.0           422.0
#
#        population  households  median_income  median_house_value  \
# 11778       443.0       170.0         6.0097            187500.0
# 18856       725.0       331.0         2.1898             65500.0
# 20018      1238.0       429.0         3.0278             77400.0
# 17657       988.0       374.0         6.0936            365400.0
# 10408       833.0       386.0         5.7709            190300.0
#
#        ocean_proximity_<1H OCEAN  ocean_proximity_INLAND  \
# 11778                          0                       1
# 18856                          0                       1
# 20018                          0                       1
# 17657                          1                       0
# 10408                          1                       0
#
#        ocean_proximity_ISLAND  ocean_proximity_NEAR BAY  \
# 11778                       0                         0
# 18856                       0                         0
# 20018                       0                         0
# 17657                       0                         0
# 10408                       0                         0
#
#        ocean_proximity_NEAR OCEAN  above_median
# 11778                           0          True
# 18856                           0         False
# 20018                           0         False
# 17657                           0          True
# 10408                           0          True

# %%
X = housing_data.drop(["median_house_value","above_median"],axis=1)
Y=housing_data["above_median"]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.2)

# %%
x_train.shape,x_test.shape
# Out:
# ((15580, 13), (3895, 13))

# %%
y_train.shape,y_test.shape
# Out:
# ((15580,), (3895,))

# %%
from sklearn.linear_model import LogisticRegression
logistic_model = LogisticRegression(solver="liblinear").fit(x_train,y_train)

# %%
print("Training Score:", logistic_model.score(x_train,y_train))
# Out:
# Training Score: 0.8197047496790757

# %%
y_pred = logistic_model.predict(x_test)

# %%
diff_pred_test = pd.DataFrame({"predicted":y_pred, "actual":y_test})
diff_pred_test
# Out:
#        predicted  actual
# 5788        True    True
# 15917      False    True
# 3168       False   False
# 1546        True    True
# 19627      False   False
# 777         True    True
# 6862        True    True
# 17187       True    True
# 15063      False   False
# 18217       True    True
# 891         True    True
# 9259       False   False
# 3209       False   False
# 12062      False   False
# 20518      False   False
# 10568       True    True
# 1143       False   False
# 2394       False   False
# 816         True    True
# 16518      False   False
# 8722        True    True
# 9856        True    True
# 4805       False   False
# 3094       False   False
# 3756        True    True
# 15916       True    True
# 10277       True    True
# 3847        True    True
# 11775      False   False
# 15711       True    True
# ...          ...     ...
# 257        False   False
# 11430       True    True
# 818        False   False
# 12075      False   False
# 18521       True    True
# 9855        True    True
# 16856       True    True
# 17748       True    True
# 3956        True    True
# 16272      False   False
# 180         True   False
# 1145       False   False
# 19552      False   False
# 4957        True   False
# 13674      False   False
# 9781       False   False
# 16054       True    True
# 10066      False   False
# 919         True    True
# 15912       True    True
# 7674        True   False
# 2900       False   False
# 8782        True    True
# 10812      False    True
# 15738      False   False
# 10067      False   False
# 16831       True    True
# 16541      False   False
# 15842       True    True
# 2411       False   False
#
# [3895 rows x 2 columns]

# %%
from sklearn.metrics import accuracy_score

# %%
print("Testing score:", accuracy_score(y_test, y_pred))
# Out:
# Testing score: 0.8233632862644416
