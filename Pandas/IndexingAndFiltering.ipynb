# %%
import pandas as pd

# %%
df = pd.read_pickle("C:\\Users\\sarth\\Documents\\Pandas\\Dataset\\collection-master\\data_frame1.pickle")

# %%
artists = df['artist']

# %%
pd.unique(artists)
# Out:
# array(['Blake, Robert', 'Blake, William', 'Richmond, George', ...,
#        'Sterne, Hedda', 'P-Orridge, Genesis', 'Brunias, Agostino'],
#       dtype=object)

# %%
len(pd.unique(artists))
# Out:
# 3336

# %%
#Find the no.of times the artist exists in the DataFrame
s = df['artist'] == "Bacon, Francis"

# %%
s.value_counts()
# Out:
# False    69151
# True        50
# Name: artist, dtype: int64

# %%
#Using value_counts() directly on the DataFrame
artist_count = df['artist'].value_counts()

# %%
artist_count['Bacon, Francis']
# Out:
# 50

# %%
artist_count
# Out:
# Turner, Joseph Mallord William       39389
# Jones, George                         1046
# Moore, Henry, OM, CH                   623
# Daniell, William                       612
# Beuys, Joseph                          578
# British (?) School                     388
# Paolozzi, Sir Eduardo                  385
# Flaxman, John                          287
# Phillips, Esq Tom                      274
# Warhol, Andy                           272
# Constable, John                        249
# Cozens, Alexander                      237
# Stothard, Thomas                       215
# Ferrari, León                          199
# Piper, John                            183
# Blake, William                         180
# Kitaj, R.B.                            179
# Dance-Holland, Sir Nathaniel           169
# Hamilton Finlay, Ian                   164
# Flanagan, Barry                        162
# Gainsborough, Thomas                   158
# Schütte, Thomas                        156
# Tilson, Joe                            152
# Roberts, William                       142
# Burne-Jones, Sir Edward Coley, Bt      138
# Hamilton, Richard                      138
# Walker, John                           135
# Pasmore, Victor                        135
# Nolan, Sir Sidney                      135
# Arnatt, Keith                          133
#                                      ...
# Gray, Ronald                             1
# Dentith, Henry                           1
# Wigram, Max                              1
# Oliveira, Nathan                         1
# Dottori, Gerardo                         1
# Cytter, Keren                            1
# Puni, Iwan                               1
# Martin, Anne                             1
# di Suvero, Mark                          1
# Boitard, Louis Philippe                  1
# Lion, Flora                              1
# Browne, Henriette                        1
# Janas, Piotr                             1
# Cowie, James                             1
# Potworowski, Peter                       1
# Finn, Michael                            1
# Turner, Winifred                         1
# Reinganum, Victor                        1
# Lethbridge, Julian                       1
# Curtis, Layla                            1
# Arnald, George                           1
# Ladbrooke, Robert                        1
# Fuller, Sue                              1
# Emanuel, Frank L.                        1
# Saunders, David                          1
# Noble, Robert                            1
# Millington, Professor                    1
# Calthrop, Claude                         1
# Swoon                                    1
# Nemon, Oscar                             1
# Name: artist, Length: 3336, dtype: int64

# %%
#usage of loc and iloc
df.loc[1035,"artist"]
# Out:
# 'Blake, Robert'

# %%
df.iloc[0,0]
# Out:
# 'Blake, Robert'

# %%
df.iloc[0,:]
# Out:
# artist                                                 Blake, Robert
# title              A Figure Bowing before a Seated Old Man with h...
# medium             Watercolour, ink, chalk and graphite on paper....
# year                                                             NaN
# acquisitionYear                                                 1922
# width                                                            394
# height                                                           419
# units                                                             mm
# Name: 1035, dtype: object

# %%
df.iloc[0:2,0:2]
# Out:
#              artist                                              title
# id
# 1035  Blake, Robert  A Figure Bowing before a Seated Old Man with h...
# 1036  Blake, Robert  Two Drawings of Frightened Figures, Probably f...

# %%
#Find the area of each artwork
df["height"]*df["width"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1504         try:
# -> 1505             result = expressions.evaluate(op, str_rep, x, y, **eval_kwargs)
#    1506         except TypeError:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr, **eval_kwargs)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b, **eval_kwargs)
#     209     return _evaluate_standard(op, op_str, a, b)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b, truediv, reversed, **eval_kwargs)
#     122     if result is None:
# --> 123         result = _evaluate_standard(op, op_str, a, b)
#     124
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b, **eval_kwargs)
#      67     with np.errstate(all='ignore'):
# ---> 68         return op(a, b)
#      69
#
# TypeError: can't multiply sequence by non-int of type 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops.py in safe_na_op(lvalues, rvalues)
#    1528             with np.errstate(all='ignore'):
# -> 1529                 return na_op(lvalues, rvalues)
#    1530         except Exception:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1506         except TypeError:
# -> 1507             result = masked_arith_op(x, y, op)
#    1508
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops.py in masked_arith_op(x, y, op)
#    1008                 result[mask] = op(xrav[mask],
# -> 1009                                   com.values_from_object(yrav[mask]))
#    1010
#
# TypeError: can't multiply sequence by non-int of type 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-0538bd86648f> in <module>
#       1 #Find the area of each artwork
# ----> 2 df["height"]*df["width"]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(left, right)
#    1581             rvalues = rvalues.values
#    1582
# -> 1583         result = safe_na_op(lvalues, rvalues)
#    1584         return construct_result(left, result,
#    1585                                 index=left.index, name=res_name, dtype=None)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops.py in safe_na_op(lvalues, rvalues)
#    1531             if is_object_dtype(lvalues):
#    1532                 return libalgos.arrmap_object(lvalues,
# -> 1533                                               lambda x: op(x, rvalues))
#    1534             raise
#    1535
#
# pandas/_libs/algos.pyx in pandas._libs.algos.arrmap()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops.py in <lambda>(x)
#    1531             if is_object_dtype(lvalues):
#    1532                 return libalgos.arrmap_object(lvalues,
# -> 1533                                               lambda x: op(x, rvalues))
#    1534             raise
#    1535
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
#above error is due to the columns width or height having non-numeric values; values in a series are always treated as objects
#convert object to numeric by below
pd.to_numeric(df["width"])  #this also fails as there are some values that cannot be converted to numeric like Strings

# %%
df.iloc[1839,:]

# %%
#We need force such values to NaN (Not a number)
pd.to_numeric(df["width"], errors="coerce")

# %%
df.iloc[0,:]
# Out:
# artist                                                 Blake, Robert
# title              A Figure Bowing before a Seated Old Man with h...
# medium             Watercolour, ink, chalk and graphite on paper....
# year                                                             NaN
# acquisitionYear                                                 1922
# width                                                            394
# height                                                           419
# units                                                             mm
# Name: 1035, dtype: object

# %%
#Feed the converted result back into the DataFrame
df.loc[:,"width"] = pd.to_numeric(df["width"],errors="coerce")

# %%
df.iloc[0,:]
# Out:
# artist                                                 Blake, Robert
# title              A Figure Bowing before a Seated Old Man with h...
# medium             Watercolour, ink, chalk and graphite on paper....
# year                                                             NaN
# acquisitionYear                                                 1922
# width                                                            394
# height                                                           419
# units                                                             mm
# Name: 1035, dtype: object

# %%
df["width"].sort_values().head()
# Out:
# id
# 9453      3.0
# 21771     5.0
# 21770     9.0
# 8976     10.0
# 509      10.0
# Name: width, dtype: float64

# %%
df["width"].sort_values().tail()
# Out:
# id
# 121283   NaN
# 117863   NaN
# 120549   NaN
# 122900   NaN
# 112306   NaN
# Name: width, dtype: float64

# %%
#similarly convert the height column to all float
df.loc[:,"height"] = pd.to_numeric(df["height"], errors = "coerce")

# %%
df["height"].sort_values().head()
# Out:
# id
# 93796      6.0
# 86955     15.0
# 123141    16.0
# 117797    17.0
# 93763     18.0
# Name: height, dtype: float64

# %%
df["height"].dtype
# Out:
# dtype('float64')

# %%
#Create a new column "area" in the DF
area = df["width"]*df["height"]
df = df.assign(area=area)

# %%
df["area"].max()
# Out:
# 132462000.0

# %%
#find the index that has maxvalue
df["area"].idxmax()
# Out:
# 98367

# %%
df.loc[98367,:]
# Out:
# artist                               Therrien, Robert
# title                No Title (Table and Four Chairs)
# medium             Aluminium, steel, wood and plastic
# year                                             2003
# acquisitionYear                                  2008
# width                                            8920
# height                                          14850
# units                                              mm
# area                                      1.32462e+08
# Name: 98367, dtype: object

# %%
#Groups and Iteration 
small_df = df.loc[3000:5000,:]

# %%
grouped  = small_df.groupby("artist")

# %%
type(grouped)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
#Iteration over the group
for name, group_df in grouped:
    print(name)
    print(group_df)
# Out:
# ?British School
#                artist                                              title  \
# id
# 6652  ?British School  Portrait of a Gentleman, probably of the West ...
#
#                 medium  year  acquisitionYear   width  height units       area
# id
# 6652  Oil paint on oak  1545           1927.0  1330.0   785.0    mm  1044050.0
# Allan, Julian Phelps
#                    artist     title                    medium  year  \
# id
# 490  Allan, Julian Phelps  Marjorie  Bronze on limestone base  1928
#
#      acquisitionYear  width  height units      area
# id
# 490           1929.0  515.0   230.0    mm  118450.0
# Austin, Robert
#              artist                         title                     medium  \
# id
# 648  Austin, Robert  Palaces, Grand Canal, Venice  Ink and graphite on paper
#
#      year  acquisitionYear  width  height units      area
# id
# 648  1925           1926.0  362.0   495.0    mm  179190.0
# Barker, Margaret
#                artist        title               medium  year  \
# id
# 721  Barker, Margaret  Any Morning  Oil paint on canvas  1929
#
#      acquisitionYear  width  height units      area
# id
# 721           1929.0  622.0   914.0    mm  568508.0
# Barker, Thomas, of Bath
#                       artist                 title               medium  year  \
# id
# 726  Barker, Thomas, of Bath  Landscape, near Bath  Oil paint on canvas  1798
#
#      acquisitionYear  width  height units      area
# id
# 726           1926.0  815.0  1070.0    mm  872050.0
# Bateman, James
#              artist     title               medium  year  acquisitionYear  \
# id
# 758  Bateman, James  Pastoral  Oil paint on canvas  1928           1929.0
#
#      width  height units       area
# id
# 758  991.0  1829.0    mm  1812539.0
# Bayes, Walter
#             artist     title               medium  year  acquisitionYear  \
# id
# 815  Bayes, Walter  The Ford  Oil paint on canvas  1917           1928.0
#
#       width  height units       area
# id
# 815  1113.0  1527.0    mm  1699551.0
# Beardsley, Aubrey
#                 artist                                              title  \
# id
# 822  Beardsley, Aubrey                 Cover Design for the ‘Yellow Book’
# 823  Beardsley, Aubrey  Design for the Frontispiece to John Davidson’s...
# 824  Beardsley, Aubrey                               Professor Fred Brown
# 825  Beardsley, Aubrey                        Messalina and her Companion
#
#                                      medium  year  acquisitionYear  width  \
# id
# 822                            Ink on paper  1894           1926.0  260.0
# 823               Ink and graphite on paper  1894           1926.0  286.0
# 824               Graphite and ink on paper  1892           1927.0  254.0
# 825  Graphite, ink and watercolour on paper  1895           1928.0  279.0
#
#      height units     area
# id
# 822   216.0    mm  56160.0
# 823   187.0    mm  53482.0
# 824   254.0    mm  64516.0
# 825   178.0    mm  49662.0
# Beerbohm, Sir Max
#                 artist                                              title  \
# id
# 874  Beerbohm, Sir Max                A Quiet Morning in the Tate Gallery
# 875  Beerbohm, Sir Max  Annual Banquet: A Suggestion to the New Englis...
#
#                                      medium  year  acquisitionYear  width  \
# id
# 874  Watercolour, graphite and ink on paper  1907           1926.0  368.0
# 875  Graphite, ink and watercolour on paper  1913           1927.0  305.0
#
#      height units      area
# id
# 874   318.0    mm  117024.0
# 875   406.0    mm  123830.0
# Belcher, George
#               artist           title                           medium  year  \
# id
# 881  Belcher, George      Well Mixed  Crayon and watercolour on paper  1909
# 882  Belcher, George  A Small Matter      Crayon and gouache on paper  1908
#
#      acquisitionYear  width  height units     area
# id
# 881           1927.0  295.0   215.0    mm  63425.0
# 882           1927.0  356.0   261.0    mm  92916.0
# Bishop, Henry
#             artist                title               medium  year  \
# id
# 984  Bishop, Henry  A Street in Carrara  Oil paint on canvas  1926
#
#      acquisitionYear  width  height units      area
# id
# 984           1927.0  382.0   461.0    mm  176102.0
# Bland, Beatrice
#                artist              title               medium  year  \
# id
# 1198  Bland, Beatrice  Striped Camellias  Oil paint on canvas  1927
#
#       acquisitionYear  width  height units      area
# id
# 1198           1929.0  457.0   349.0    mm  159493.0
# Bonington, Richard Parkes
#                          artist                title               medium  \
# id
# 1307  Bonington, Richard Parkes   Mountain Landscape   Oil paint on paper
# 1306  Bonington, Richard Parkes  On the French Coast  Oil paint on canvas
#
#      year  acquisitionYear  width  height units      area
# id
# 1307  NaN           1927.0  267.0   343.0    mm   91581.0
# 1306  NaN           1927.0  381.0   533.0    mm  203073.0
# Bonnard, Pierre
#                artist       title               medium  year  acquisitionYear  \
# id
# 1309  Bonnard, Pierre   The Table  Oil paint on canvas  1925           1926.0
# 1310  Bonnard, Pierre  The Window  Oil paint on canvas  1925           1930.0
# 1311  Bonnard, Pierre    The Bath  Oil paint on canvas  1925           1930.0
#
#        width  height units       area
# id
# 1309  1029.0   743.0    mm   764547.0
# 1310  1086.0   886.0    mm   962196.0
# 1311   860.0  1206.0    mm  1037160.0
# Braque, Georges
#                artist                      title               medium  year  \
# id
# 1442  Braque, Georges  Glass and Plate of Apples   Oil paint on board  1925
# 1443  Braque, Georges             Guitar and Jug  Oil paint on canvas  1927
#
#       acquisitionYear  width  height units      area
# id
# 1442           1926.0  400.0   600.0    mm  240000.0
# 1443           1928.0  810.0  1165.0    mm  943650.0
# British (?) School 19th century
#                                artist                      title  \
# id
# 1534  British (?) School 19th century  A Painter’s Self-Portrait
#
#                    medium year  acquisitionYear  width  height units      area
# id
# 1534  Oil paint on canvas  NaN           1929.0  597.0   495.0    mm  295515.0
# Brown, Ford Madox
#                  artist                                              title  \
# id
# 1605  Brown, Ford Madox  Study for the Dean in the ‘Execution of Mary Q...
# 1606  Brown, Ford Madox            Sketch for ‘Jesus Washing Peter’s Feet’
# 1607  Brown, Ford Madox                  Sketch for ‘Cromwell on his Farm’
# 1608  Brown, Ford Madox                               ‘Take your Son, Sir’
#
#                    medium  year  acquisitionYear  width  height units  \
# id
# 1605   Oil paint on paper  1840           1927.0  470.0   394.0    mm
# 1606    Graphite on paper  1852           1927.0  171.0   200.0    mm
# 1607    Graphite on paper  1853           1927.0  146.0    98.0    mm
# 1608  Oil paint on canvas  1851           1929.0  705.0   381.0    mm
#
#           area
# id
# 1605  185180.0
# 1606   34200.0
# 1607   14308.0
# 1608  268605.0
# Burn, Rodney J.
#                artist            title                        medium  year  \
# id
# 1691  Burn, Rodney J.  The Pick-a-Back  Ink and watercolour on paper  1925
#
#       acquisitionYear  width  height units      area
# id
# 1691           1927.0  495.0   279.0    mm  138105.0
# Burne-Jones, Sir Edward Coley, Bt
#                                  artist  \
# id
# 1804  Burne-Jones, Sir Edward Coley, Bt
# 1805  Burne-Jones, Sir Edward Coley, Bt
# 1806  Burne-Jones, Sir Edward Coley, Bt
# 1807  Burne-Jones, Sir Edward Coley, Bt
# 1808  Burne-Jones, Sir Edward Coley, Bt
# 1809  Burne-Jones, Sir Edward Coley, Bt
#
#                                                   title  \
# id
# 1804  Cartoon for ‘St Agnes’, for St Helen’s Church,...
# 1805    Figure Study. Verso: Study for an Annunciation?
# 1806  Studies of Drapery and the Figure of the Virgi...
# 1807                             Study for ‘Cinderella’
# 1808                    Study for ‘The Mirror of Venus’
# 1809                                     Clerk Saunders
#
#                                            medium  year  acquisitionYear  \
# id
# 1804                  Graphite and chalk on paper  1876           1927.0
# 1805  Graphite on paper. Verso: graphite on paper   NaN           1927.0
# 1806                            Graphite on paper  1862           1927.0
# 1807                            Graphite on paper  1863           1927.0
# 1808                  Charcoal and chalk on paper   NaN           1927.0
# 1809                         Watercolour on paper  1861           1927.0
#
#        width  height units      area
# id
# 1804  1195.0   458.0    mm  547310.0
# 1805   279.0   178.0    mm   49662.0
# 1806   340.0   362.0    mm  123080.0
# 1807   337.0   197.0    mm   66389.0
# 1808   283.0   238.0    mm   67354.0
# 1809   699.0   418.0    mm  292182.0
# Bussy, Simon
#             artist      title           medium  year  acquisitionYear  width  \
# id
# 1865  Bussy, Simon  Landscape  Pastel on paper  1902           1927.0  184.0
#
#       height units     area
# id
# 1865   184.0    mm  33856.0
# Caldecott, Randolph
#                    artist                  title  \
# id
# 1894  Caldecott, Randolph  Scene in a Churchyard
# 1895  Caldecott, Randolph             Tug of War
#
#                                 medium  year  acquisitionYear  width  height  \
# id
# 1894  Watercolour and gouache on paper   NaN           1927.0  216.0   305.0
# 1895                      Ink on paper  1877           1927.0  175.0   260.0
#
#      units     area
# id
# 1894    mm  65880.0
# 1895    mm  45500.0
# Calderon, Philip Hermogenes
#                            artist  \
# id
# 1901  Calderon, Philip Hermogenes
#
#                                                 title  \
# id
# 1901  Half Hours with the Best Authors (‘The Siesta’)
#
#                                 medium  year  acquisitionYear  width  height  \
# id
# 1901  Watercolour and gouache on paper  1866           1922.0  178.0   279.0
#
#      units     area
# id
# 1901    mm  49662.0
# Cameron, Katherine
#                   artist              title  \
# id
# 1966  Cameron, Katherine  The Mountain Fern
#
#                                  medium  year  acquisitionYear  width  height  \
# id
# 1966  Graphite and watercolour on paper  1923           1930.0  510.0   285.0
#
#      units      area
# id
# 1966    mm  145350.0
# Carline, Sydney
#                artist                                 title  \
# id
# 1988  Carline, Sydney  St John’s, Downshire Hill, Hampstead
#
#                    medium  year  acquisitionYear  width  height units  \
# id
# 1988  Oil paint on canvas  1927           1929.0  648.0   540.0    mm
#
#           area
# id
# 1988  349920.0
# Carrière, Eugène
#                 artist         title               medium  year  \
# id
# 2001  Carrière, Eugène  Winding Wool  Oil paint on canvas  1887
#
#       acquisitionYear  width  height units      area
# id
# 2001           1927.0  876.0   995.0    mm  871620.0
# Cazin, Jean-Charles
#                    artist                        title               medium  \
# id
# 2088  Cazin, Jean-Charles  Ulysses after the Shipwreck  Oil paint on canvas
#
#       year  acquisitionYear  width  height units      area
# id
# 2088  1890           1927.0  733.0   597.0    mm  437601.0
# Cheston, Charles
#                 artist     title                medium  year  acquisitionYear  \
# id
# 2186  Cheston, Charles  Ramsgate  Watercolour on paper  1928           1929.0
#
#       width  height units      area
# id
# 2186  273.0   378.0    mm  103194.0
# Ciardi, Emma
#             artist           title               medium  year  \
# id
# 2225  Ciardi, Emma  Diaphanous Day  Oil paint on canvas  1924
#
#       acquisitionYear  width  height units      area
# id
# 2225           1928.0  603.0   807.0    mm  486621.0
# Clarke Hall, Lady Edna
#                       artist                   title                medium  \
# id
# 2259  Clarke Hall, Lady Edna  Girl Leaning on a Gate  Watercolour on paper
#
#       year  acquisitionYear  width  height units     area
# id
# 2259  1915           1927.0  311.0   241.0    mm  74951.0
# Clausen, Sir George
#                    artist                   title               medium  year  \
# id
# 2275  Clausen, Sir George                A Dancer  Oil paint on canvas  1929
# 2276  Clausen, Sir George              Brown Eyes  Oil paint on canvas  1891
# 2277  Clausen, Sir George  A Frosty March Morning  Oil paint on canvas  1904
# 2278  Clausen, Sir George    Gleaners Coming Home  Oil paint on canvas  1904
#
#       acquisitionYear  width  height units       area
# id
# 2275           1929.0  457.0   356.0    mm   162692.0
# 2276           1929.0  559.0   413.0    mm   230867.0
# 2277           1929.0  635.0   762.0    mm   483870.0
# 2278           1929.0  927.0  1226.0    mm  1136502.0
# Collier, The Hon. John
#                       artist       title               medium  year  \
# id
# 2469  Collier, The Hon. John  Mrs Huxley  Oil paint on canvas  1927
#
#       acquisitionYear  width  height units      area
# id
# 2469           1928.0  610.0   508.0    mm  309880.0
# Conder, Charles
#                artist                                              title  \
# id
# 2549  Conder, Charles                                         Springtime
# 2550  Conder, Charles                                   The New Moon Fan
# 2551  Conder, Charles                                            Swanage
# 2552  Conder, Charles                                        Swanage Bay
# 2553  Conder, Charles                                By the Sea: Swanage
# 2554  Conder, Charles  Portrait Study.  Verso: Study of a Man in Bed ...
# 2555  Conder, Charles                                     Portrait Study
# 2556  Conder, Charles                                              A Fan
#
#                                     medium  year  acquisitionYear  width  \
# id
# 2549                   Oil paint on canvas  1892           1926.0  730.0
# 2550                 Watercolour on fabric  1896           1927.0  216.0
# 2551                   Oil paint on canvas  1901           1928.0  229.0
# 2552                   Oil paint on canvas  1901           1928.0  457.0
# 2553                   Oil paint on canvas  1901           1928.0  229.0
# 2554                    Oil paint on board  1901           1930.0  432.0
# 2555                    Oil paint on board  1901           1930.0  432.0
# 2556  Watercolour and silver paint on silk  1893           1930.0  215.0
#
#       height units      area
# id
# 2549   593.0    mm  432890.0
# 2550   451.0    mm   97416.0
# 2551   305.0    mm   69845.0
# 2552   610.0    mm  278770.0
# 2553   305.0    mm   69845.0
# 2554   311.0    mm  134352.0
# 2555   318.0    mm  137376.0
# 2556   440.0    mm   94600.0
# Connard, Philip
#                artist               title  \
# id
# 2564  Connard, Philip    Le Petit Journal
# 2565  Connard, Philip  Woman on a Balcony
#
#                                       medium  year  acquisitionYear  width  \
# id
# 2564  Graphite, ink and watercolour on paper  1926           1927.0  267.0
# 2565                     Oil paint on canvas  1909           1928.0  610.0
#
#       height units      area
# id
# 2564   343.0    mm   91581.0
# 2565   508.0    mm  309880.0
# Constable, John
#                artist                                              title  \
# id
# 2616  Constable, John  Branch Hill Pond, Hampstead Heath, with a Cart...
#
#                    medium  year  acquisitionYear  width  height units  \
# id
# 2616  Oil paint on canvas  1825           1927.0  537.0   768.0    mm
#
#           area
# id
# 2616  412416.0
# Cotes, Francis
#               artist                    title               medium  year  \
# id
# 2806  Cotes, Francis  A Gentleman with a Cane  Oil paint on canvas  1765
#
#       acquisitionYear  width  height units      area
# id
# 2806           1928.0  908.0   705.0    mm  640140.0
# Cotman, John Sell
#                  artist          title                             medium  \
# id
# 2821  Cotman, John Sell  Mountain Lake  Watercolour and graphite on paper
#
#       year  acquisitionYear  width  height units     area
# id
# 2821  1804           1926.0  162.0   283.0    mm  45846.0
# Cox, David
#            artist                                              title  \
# id
# 21008  Cox, David  Crypt of Kirkstall Abbey (after J.M.W. Turner)...
# 2866   Cox, David               Calais: Street Scene with Lighthouse
# 2867   Cox, David                      Near the Pont d’Arcole, Paris
# 2868   Cox, David                             Calais: Hôtel de Guise
# 2869   Cox, David                         Westminster from Battersea
# 2870   Cox, David                       Caernarvon Castle with Boats
# 2871   Cox, David               Buildings on the Banks of the Thames
# 2872   Cox, David                                         Still Life
# 2873   Cox, David                                           Windmill
# 2874   Cox, David                                  Houses at Dulwich
# 2875   Cox, David                        Landscape with Salmon Traps
# 2876   Cox, David                    Coast Scene. Verso: Coast Scene
# 2877   Cox, David                      A Ship. Verso: Open Landscape
#
#                                                   medium  year  \
# id
# 21008  Graphite and watercolour on paper. Verso: wate...   NaN
# 2866                   Graphite and watercolour on paper  1829
# 2867                   Watercolour and graphite on paper  1829
# 2868                   Watercolour and graphite on paper  1829
# 2869                                Watercolour on board   NaN
# 2870                                Watercolour on paper   NaN
# 2871                                Watercolour on paper   NaN
# 2872                                Watercolour on paper   NaN
# 2873                                Watercolour on board   NaN
# 2874                                Watercolour on paper   NaN
# 2875                     Crayon and watercolour on paper   NaN
# 2876   Watercolour and graphite on paper. Verso: grap...   NaN
# 2877      Watercolour on paper. Verso: graphite on paper   NaN
#
#        acquisitionYear  width  height units      area
# id
# 21008           1927.0  185.0   265.0    mm   49025.0
# 2866            1927.0  162.0   254.0    mm   41148.0
# 2867            1927.0  258.0   371.0    mm   95718.0
# 2868            1927.0  162.0   216.0    mm   34992.0
# 2869            1927.0  133.0   241.0    mm   32053.0
# 2870            1927.0  149.0   298.0    mm   44402.0
# 2871            1927.0  143.0   305.0    mm   43615.0
# 2872            1927.0  171.0   210.0    mm   35910.0
# 2873            1927.0  225.0   159.0    mm   35775.0
# 2874            1927.0  178.0   152.0    mm   27056.0
# 2875            1927.0  330.0   530.0    mm  174900.0
# 2876            1927.0  273.0   387.0    mm  105651.0
# 2877            1927.0  152.0   200.0    mm   30400.0
# Cozens, John Robert
#                    artist                               title  \
# id
# 2912  Cozens, John Robert  Lake of Albano and Castel Gandolfo
#
#                     medium  year  acquisitionYear  width  height units  \
# id
# 2912  Watercolour on paper  1783           1928.0  489.0   679.0    mm
#
#           area
# id
# 2912  332031.0
# Dadd, Richard
#              artist           title                             medium  year  \
# id
# 2976  Dadd, Richard  The Pilot Boat  Watercolour and graphite on paper  1858
#
#       acquisitionYear  width  height units      area
# id
# 2976           1930.0  283.0   451.0    mm  127633.0
# Dalziel, Edward Gurden
#                       artist           title                   medium  year  \
# id
# 3000  Dalziel, Edward Gurden  Spring Flowers  Wood engraving on paper  1869
#
#       acquisitionYear  width  height units     area
# id
# 3000           1925.0  175.0   121.0    mm  21175.0
# Dalziel, Thomas
#                artist      title                   medium  year  \
# id
# 3001  Dalziel, Thomas  The Alarm  Wood engraving on paper  1864
#
#       acquisitionYear  width  height units     area
# id
# 3001           1925.0  171.0   130.0    mm  22230.0
# Dinkel, Ernest M.
#                  artist       title           medium  year  acquisitionYear  \
# id
# 3925  Dinkel, Ernest M.  The Deluge  Tempera on wood  1929           1929.0
#
#       width  height units      area
# id
# 3925  472.0   468.0    mm  220896.0
# Dobson, Frank
#              artist           title                    medium  year  \
# id
# 3942  Dobson, Frank  Head of a Girl  Bronze on limestone base  1925
# 3943  Dobson, Frank           Truth                    Bronze  1930
#
#       acquisitionYear   width  height units      area
# id
# 3942           1929.0   410.0   250.0    mm  102500.0
# 3943           1930.0  1245.0   800.0    mm  996000.0
# Dodd, Francis
#              artist              title                medium  year  \
# id
# 3960  Dodd, Francis     Edward Garnett     Charcoal on paper  1926
# 3961  Dodd, Francis  Cumberland Market  Watercolour on paper   NaN
#
#       acquisitionYear  width  height units      area
# id
# 3960           1926.0  379.0   280.0    mm  106120.0
# 3961           1930.0  203.0   229.0    mm   46487.0
# Dufresne, Charles
#                  artist                     title  \
# id
# 4032  Dufresne, Charles  Spahi Attacked by a Lion
#
#                                 medium  year  acquisitionYear  width  height  \
# id
# 4032  Watercolour and gouache on paper  1919           1926.0  394.0   505.0
#
#      units      area
# id
# 4032    mm  198970.0
# Edridge, Henry
#               artist                title             medium  year  \
# id
# 4081  Edridge, Henry  Landscape with Mill  Graphite on paper   NaN
# 4082  Edridge, Henry  Seashore with Cliff  Graphite on paper  1818
#
#       acquisitionYear  width  height units      area
# id
# 4081           1927.0  257.0   400.0    mm  102800.0
# 4082           1927.0  241.0   375.0    mm   90375.0
# Epstein, Sir Jacob
#                   artist                 title             medium  year  \
# id
# 4112  Epstein, Sir Jacob        The Visitation             Bronze  1926
# 4113  Epstein, Sir Jacob  Mrs Godfrey Phillips             Bronze  1928
# 4114  Epstein, Sir Jacob    The Little Negress  Graphite on paper  1928
# 4115  Epstein, Sir Jacob               Negress  Graphite on paper  1928
#
#       acquisitionYear   width  height units      area
# id
# 4112           1927.0  1651.0   470.0    mm  775970.0
# 4113           1928.0   457.0   432.0    mm  197424.0
# 4114           1928.0   476.0   559.0    mm  266084.0
# 4115           1928.0   457.0   559.0    mm  255463.0
# Etty, William
#              artist                                            title  \
# id
# 4176  Etty, William  Study of a Peacock for ‘The Judgement of Paris’
#
#                   medium  year  acquisitionYear  width  height units      area
# id
# 4176  Oil paint on board  1826           1928.0  502.0   641.0    mm  321782.0
# Eves, Reginald G
#                 artist         title               medium  year  \
# id
# 4204  Eves, Reginald G  Thomas Hardy  Oil paint on canvas  1924
#
#       acquisitionYear  width  height units      area
# id
# 4204           1929.0  762.0   635.0    mm  483870.0
# Farington, Joseph
#                  artist                                           title  \
# id
# 4228  Farington, Joseph  Landscape at Sandringham, with Trees and Wagon
# 4229  Farington, Joseph                          Landscape, with Castle
# 4230  Farington, Joseph                              Cockermouth Castle
#
#                             medium  year  acquisitionYear  width  height  \
# id
# 4228  Ink and watercolour on paper  1787           1927.0  219.0   270.0
# 4229  Ink and watercolour on paper  1787           1927.0  295.0   222.0
# 4230  Ink and watercolour on paper  1786           1927.0  159.0   298.0
#
#      units     area
# id
# 4228    mm  59130.0
# 4229    mm  65490.0
# 4230    mm  47382.0
# Garbe, Richard
#               artist     title medium  year  acquisitionYear  width  height  \
# id
# 4967  Garbe, Richard  Sea Lion  Stone  1929           1929.0  756.0   552.0
#
#      units      area
# id
# 4967    mm  417312.0
# Garstin, Norman
#                artist                        title             medium  year  \
# id
# 4975  Garstin, Norman  A Woman Reading a Newspaper  Oil paint on wood  1891
#
#       acquisitionYear  width  height units     area
# id
# 4975           1927.0  254.0   216.0    mm  54864.0
# Gaudier-Brzeska, Henri
#                       artist                             title  \
# id
# 4983  Gaudier-Brzeska, Henri                            Singer
# 4984  Gaudier-Brzeska, Henri                  Red Stone Dancer
# 4985  Gaudier-Brzeska, Henri                           The Imp
# 4986  Gaudier-Brzeska, Henri                    Man on a Horse
# 4987  Gaudier-Brzeska, Henri                   Head of a Child
# 4988  Gaudier-Brzeska, Henri                    Head of a Girl
# 4989  Gaudier-Brzeska, Henri                             Tiger
# 4990  Gaudier-Brzeska, Henri                              Lion
# 4991  Gaudier-Brzeska, Henri                         Leopard I
# 4992  Gaudier-Brzeska, Henri                        Leopard II
# 4993  Gaudier-Brzeska, Henri                            Jaguar
# 4994  Gaudier-Brzeska, Henri                            Puma I
# 4995  Gaudier-Brzeska, Henri                           Puma II
# 4996  Gaudier-Brzeska, Henri                             Eland
# 4997  Gaudier-Brzeska, Henri  Verso: Traces of Sketch of Bison
# 4998  Gaudier-Brzeska, Henri                  Studies of Birds
# 4999  Gaudier-Brzeska, Henri                         Vulture I
# 5000  Gaudier-Brzeska, Henri                        Vulture II
#
#                    medium  year  acquisitionYear  width  height units  \
# id
# 4983          Derby stone  1913           1930.0  851.0   216.0    mm
# 4984  Red Mansfield stone  1913           1930.0  432.0   229.0    mm
# 4985            Alabaster  1914           1930.0  406.0    89.0    mm
# 4986         Ink on paper  1913           1930.0  419.0   521.0    mm
# 4987         Ink on paper  1912           1930.0  387.0   254.0    mm
# 4988         Ink on paper  1912           1930.0  381.0   254.0    mm
# 4989         Ink on paper  1913           1930.0  387.0   260.0    mm
# 4990         Ink on paper  1912           1930.0  235.0   349.0    mm
# 4991         Ink on paper  1912           1930.0  254.0   387.0    mm
# 4992         Ink on paper  1912           1930.0  254.0   387.0    mm
# 4993         Ink on paper  1912           1930.0  254.0   387.0    mm
# 4994         Ink on paper  1912           1930.0  203.0   368.0    mm
# 4995         Ink on paper  1912           1930.0  254.0   387.0    mm
# 4996         Ink on paper  1912           1930.0  254.0   387.0    mm
# 4997         Ink on paper  1912           1930.0  216.0   343.0    mm
# 4998         Ink on paper  1912           1930.0  254.0   356.0    mm
# 4999         Ink on paper  1912           1930.0  387.0   254.0    mm
# 5000         Ink on paper  1912           1930.0  387.0   254.0    mm
#
#           area
# id
# 4983  183816.0
# 4984   98928.0
# 4985   36134.0
# 4986  218299.0
# 4987   98298.0
# 4988   96774.0
# 4989  100620.0
# 4990   82015.0
# 4991   98298.0
# 4992   98298.0
# 4993   98298.0
# 4994   74704.0
# 4995   98298.0
# 4996   98298.0
# 4997   74088.0
# 4998   90424.0
# 4999   98298.0
# 5000   98298.0
# Gere, Charles M.
#                 artist          title                                medium  \
# id
# 5114  Gere, Charles M.       Provence  Ink, crayon and watercolour on paper
# 5115  Gere, Charles M.  Trial by Jury     Graphite and watercolour on paper
#
#       year  acquisitionYear  width  height units      area
# id
# 5114  1926           1927.0  324.0   457.0    mm  148068.0
# 5115  1919           1930.0  270.0   375.0    mm  101250.0
# Gethin, Percy Francis
#                      artist                                title  \
# id
# 5131  Gethin, Percy Francis  Sémur, General View through Viaduct
# 5132  Gethin, Percy Francis                              Athlone
# 5133  Gethin, Percy Francis             View from Château Chinon
#
#                                       medium  year  acquisitionYear  width  \
# id
# 5131  Ink, graphite and watercolour on paper  1911           1926.0  346.0
# 5132            Watercolour and ink on paper   NaN           1926.0  203.0
# 5133                    Watercolour on paper  1911           1926.0  219.0
#
#       height units     area
# id
# 5131   263.0    mm  90998.0
# 5132   305.0    mm  61915.0
# 5133   279.0    mm  61101.0
# Gibb, Phelan
#             artist                                title                medium  \
# id
# 5161  Gibb, Phelan  Belgrave Square and Wilton Crescent  Watercolour on paper
#
#       year  acquisitionYear  width  height units      area
# id
# 5161  1928           1928.0  343.0   483.0    mm  165669.0
# Gilbert, Sir Alfred
#                    artist                                              title  \
# id
# 5168  Gilbert, Sir Alfred  Model for ‘Eros’ on the Shaftesbury Memorial, ...
#
#                      medium  year  acquisitionYear  width  height units  \
# id
# 5168  Bronze on marble base  1891           1925.0  730.0   278.0    mm
#
#           area
# id
# 5168  202940.0
# Gill, Eric
#           artist          title      medium  year  acquisitionYear  width  \
# id
# 5206  Gill, Eric  The East Wind  Bath stone  1929           1929.0  254.0
#
#       height units      area
# id
# 5206   705.0    mm  179070.0
# Gilman, Harold
#               artist         title               medium  year  \
# id
# 5340  Gilman, Harold  Leeds Market  Oil paint on canvas  1913
#
#       acquisitionYear  width  height units      area
# id
# 5340           1927.0  508.0   610.0    mm  309880.0
# Girtin, Thomas
#               artist                            title  \
# id
# 5363  Girtin, Thomas       The River Tweed near Kelso
# 5365  Girtin, Thomas  Bamburgh Castle, Northumberland
#
#                                           medium  year  acquisitionYear  \
# id
# 5363                        Watercolour on paper  1800           1927.0
# 5365  Watercolour, gouache and graphite on paper  1797           1928.0
#
#       width  height units      area
# id
# 5363  267.0   324.0    mm   86508.0
# 5365  549.0   451.0    mm  247599.0
# Goodwin, Albert
#                artist      title                medium year  acquisitionYear  \
# id
# 5511  Goodwin, Albert  Salisbury  Watercolour on paper  NaN           1926.0
#
#       width  height units     area
# id
# 5511   95.0   140.0    mm  13300.0
# Gordine, Dora
#              artist           title                 medium  year  \
# id
# 5512  Gordine, Dora  Mongolian Head  Bronze on wooden base  1928
#
#       acquisitionYear  width  height units      area
# id
# 5512           1928.0  490.0   210.0    mm  102900.0
# Gosse, Sylvia
#              artist                   title               medium  year  \
# id
# 5540  Gosse, Sylvia  Walter Richard Sickert  Oil paint on canvas  1923
#
#       acquisitionYear  width  height units      area
# id
# 5540           1927.0  508.0   305.0    mm  154940.0
# Grant, Duncan
#              artist            title               medium  year  \
# id
# 5575  Grant, Duncan  South of France  Oil paint on canvas  1922
#
#       acquisitionYear  width  height units      area
# id
# 5575           1929.0  648.0   806.0    mm  522288.0
# Graveney, William
#                  artist       title medium  year  acquisitionYear  width  \
# id
# 5599  Graveney, William  Cormorants   Wood  1926           1926.0  235.0
#
#       height units     area
# id
# 5599   254.0    mm  59690.0
# Gray, Douglas S.
#                 artist     title               medium  year  acquisitionYear  \
# id
# 5601  Gray, Douglas S.  Rosalind  Oil paint on canvas  1924           1926.0
#
#        width  height units       area
# id
# 5601  1295.0   927.0    mm  1200465.0
# Greiffenhagen, Maurice
#                       artist title                medium  year  \
# id
# 5678  Greiffenhagen, Maurice  Dawn  Oil paint on plywood  1926
#
#       acquisitionYear  width  height units       area
# id
# 5678           1926.0  959.0  2019.0    mm  1936221.0
# Guthrie, Robin
#               artist            title               medium  year  \
# id
# 5743  Guthrie, Robin  Head of a Woman  Oil paint on canvas  1921
#
#       acquisitionYear  width  height units      area
# id
# 5743           1927.0  508.0   406.0    mm  206248.0
# Hammershoi, Vilhelm
#                    artist                            title  \
# id
# 5835  Hammershoi, Vilhelm  Interior, Sunlight on the Floor
#
#                    medium  year  acquisitionYear  width  height units  \
# id
# 5835  Oil paint on canvas  1906           1930.0  518.0   440.0    mm
#
#           area
# id
# 5835  227920.0
# Hills, Robert
#              artist                                    title  \
# id
# 6445  Hills, Robert                        Study of a Donkey
# 6446  Hills, Robert  The Priory, Tonbridge: 3 small sketches
# 6447  Hills, Robert                A Farm and Study of a Man
# 6448  Hills, Robert                               A Farmyard
# 6449  Hills, Robert                                   A Barn
#
#                                  medium year  acquisitionYear  width  height  \
# id
# 6445               Watercolour on paper  NaN           1927.0  190.0   248.0
# 6446               Watercolour on paper  NaN           1927.0  279.0   190.0
# 6447  Graphite and watercolour on paper  NaN           1927.0  203.0   305.0
# 6448               Watercolour on paper  NaN           1927.0  178.0   264.0
# 6449               Watercolour on paper  NaN           1927.0  133.0   229.0
#
#      units     area
# id
# 6445    mm  47120.0
# 6446    mm  53010.0
# 6447    mm  61915.0
# 6448    mm  46992.0
# 6449    mm  30457.0
# Holland, James
#               artist                            title               medium  \
# id
# 6666  Holland, James  The Thames below Woolwich, 1843  Oil paint on canvas
#
#      year  acquisitionYear  width  height units      area
# id
# 6666  NaN           1927.0  610.0   508.0    mm  309880.0
# Holloway, Charles Edward
#                         artist                                 title  \
# id
# 6668  Holloway, Charles Edward  The St Vincent in Portsmouth Harbour
#
#                    medium  year  acquisitionYear  width  height units     area
# id
# 6668  Oil paint on canvas  1893           1926.0  356.0   254.0    mm  90424.0
# Holmes, Sir Charles John
#                         artist      title               medium  year  \
# id
# 6674  Holmes, Sir Charles John  Whernside  Oil paint on canvas  1917
#
#       acquisitionYear  width  height units      area
# id
# 6674           1928.0  686.0   762.0    mm  522732.0
# Holroyd, Sir Charles
#                     artist                title               medium  year  \
# id
# 6680  Holroyd, Sir Charles  Death of Torrigiano  Oil paint on canvas  1886
#
#       acquisitionYear  width  height units       area
# id
# 6680           1928.0  935.0  1211.0    mm  1132285.0
# Hornel, Edward Atkinson
#                        artist   title               medium  year  \
# id
# 6716  Hornel, Edward Atkinson  Autumn  Oil paint on canvas  1904
#
#       acquisitionYear   width  height units       area
# id
# 6716           1928.0  1168.0  1022.0    mm  1193696.0
# Houghton, Arthur Boyd
#                      artist  \
# id
# 6745  Houghton, Arthur Boyd
# 6746  Houghton, Arthur Boyd
# 6747  Houghton, Arthur Boyd
# 6748  Houghton, Arthur Boyd
# 6749  Houghton, Arthur Boyd
# 6750  Houghton, Arthur Boyd
# 6751  Houghton, Arthur Boyd
# 6752  Houghton, Arthur Boyd
# 6753  Houghton, Arthur Boyd
# 6754  Houghton, Arthur Boyd
# 6755  Houghton, Arthur Boyd
# 6756  Houghton, Arthur Boyd
# 6757  Houghton, Arthur Boyd
# 6758  Houghton, Arthur Boyd
# 6759  Houghton, Arthur Boyd
# 6760  Houghton, Arthur Boyd
#
#                                                   title  \
# id
# 6745                        Mother and Children Reading
# 6746                                   Lady with a Book
# 6747  The African Magician Offers New Lamps for Old,...
# 6748  The Indian Prostrates Himself Before the King ...
# 6749     Scene from ‘The Arabian Nights’, for engraving
# 6750     Scene from ‘The Arabian Nights’, for engraving
# 6751         Old Woman Seated in a Chair, for engraving
# 6752                        London Scene, for engraving
# 6753                   Facing the Camera, for engraving
# 6754            Scene from ‘Don Quixote’, for engraving
# 6755  My Treasure: Mrs A.B. Houghton and Two Childre...
# 6756                                         Volunteers
# 6757                              The Don on the Island
# 6758                                    Head of a Child
# 6759                                   Study of a Woman
# 6760                          Head of a Woman and Child
#
#                              medium  year  acquisitionYear  width  height  \
# id
# 6745            Oil paint on canvas  1860           1926.0  305.0   248.0
# 6746            Oil paint on canvas  1860           1926.0  241.0   190.0
# 6747  Graphite on painted woodblock  1864           1926.0  171.0   127.0
# 6748  Graphite on painted woodblock  1864           1926.0  171.0   127.0
# 6749  Graphite on painted woodblock  1864           1926.0  127.0    79.0
# 6750  Graphite on painted woodblock   NaN           1926.0   95.0   127.0
# 6751   Ink and gouache on woodblock   NaN           1926.0  159.0   108.0
# 6752   Ink and gouache on woodblock   NaN           1926.0  105.0    89.0
# 6753   Ink and gouache on woodblock  1865           1926.0  133.0   102.0
# 6754  Graphite on painted woodblock  1866           1926.0   89.0    95.0
# 6755        Wood engraving on paper   NaN           1926.0  165.0   121.0
# ...
# 13675                                Oil paint on canvas  1924
# 13676  Graphite and watercolour on paper. Verso: grap...  1922
#
#        acquisitionYear   width  height units        area
# id
# 13675           1927.0  2743.0  5486.0    mm  15048098.0
# 13676           1927.0   505.0   371.0    mm    187355.0
# Stanhope, John Roddam Spencer
#                               artist           title               medium  \
# id
# 13756  Stanhope, John Roddam Spencer  The Wine Press  Oil paint on canvas
#
#        year  acquisitionYear  width  height units      area
# id
# 13756  1864           1930.0  940.0   667.0    mm  626980.0
# Steer, Philip Wilson
#                      artist                                          title  \
# id
# 13783  Steer, Philip Wilson                                          Sleep
# 13784  Steer, Philip Wilson                            The Toilet of Venus
# 13785  Steer, Philip Wilson  Mrs Cyprian Williams and her Two Little Girls
# 13786  Steer, Philip Wilson                                      Bathsheba
# 13787  Steer, Philip Wilson                    Stroud: An Upland Landscape
#
#                     medium  year  acquisitionYear   width  height units  \
# id
# 13783  Oil paint on canvas  1898           1927.0   895.0  1321.0    mm
# 13784  Oil paint on canvas  1898           1927.0  2553.0  1835.0    mm
# 13785  Oil paint on canvas  1891           1928.0   762.0  1022.0    mm
# 13786  Oil paint on canvas  1919           1929.0   660.0   508.0    mm
# 13787  Oil paint on canvas  1902           1929.0   514.0   692.0    mm
#
#             area
# id
# 13783  1182295.0
# 13784  4684755.0
# 13785   778764.0
# 13786   335280.0
# 13787   355688.0
# Stevens, Alfred
#                 artist             title               medium  year  \
# id
# 13868  Stevens, Alfred     Samuel Pegler  Oil paint on canvas  1832
# 13869  Stevens, Alfred  Miss Emma Pegler  Oil paint on canvas  1832
#
#        acquisitionYear  width  height units      area
# id
# 13868           1926.0  460.0   381.0    mm  175260.0
# 13869           1928.0  533.0   432.0    mm  230256.0
# Stevenson, Robert Alan Mowbray
#                                artist           title               medium  \
# id
# 13889  Stevenson, Robert Alan Mowbray  Houses in Snow  Oil paint on canvas
#
#       year  acquisitionYear  width  height units      area
# id
# 13889  NaN           1926.0  610.0   464.0    mm  283040.0
# Stothard, Thomas
#                  artist                    title  \
# id
# 13943  Stothard, Thomas  Study of Female Figures
#
#                              medium year  acquisitionYear  width  height  \
# id
# 13943  Ink and watercolour on paper  NaN           1927.0  152.0   102.0
#
#       units     area
# id
# 13943    mm  15504.0
# Strang, William
#                 artist                title                          medium  \
# id
# 13956  Strang, William  Mrs James MacLehose  Chalk and watercolour on paper
#
#        year  acquisitionYear  width  height units      area
# id
# 13956  1903           1929.0  416.0   273.0    mm  113568.0
# Swynnerton, Annie Louisa
#                          artist             title               medium  year  \
# id
# 14099  Swynnerton, Annie Louisa  The Convalescent  Oil paint on canvas  1929
#
#        acquisitionYear  width  height units      area
# id
# 14099           1929.0  571.0   635.0    mm  362585.0
# Thirtle, John
#               artist     title                medium year  acquisitionYear  \
# id
# 14142  Thirtle, John  Old Lynn  Watercolour on paper  NaN           1928.0
#
#        width  height units      area
# id
# 14142  359.0   530.0    mm  190270.0
# Thomas, George Housman
#                        artist  \
# id
# 14143  Thomas, George Housman
#
#                                                    title  \
# id
# 14143  Three Drawings for Illustration.  i) A Cab for...
#
#                                  medium year  acquisitionYear  width  height  \
# id
# 14143  Watercolour and gouache on paper  NaN           1927.0  149.0   190.0
#
#       units     area
# id
# 14143    mm  28310.0
# Thomas, James Havard
#                      artist    title        medium  year  acquisitionYear  \
# id
# 14150  Thomas, James Havard  Thyrsis  Wax and wood  1912           1926.0
#
#         width  height units       area
# id
# 14150  1683.0   702.0    mm  1181466.0
# Thornycroft, Sir Hamo
#                       artist                                 title  \
# id
# 14174  Thornycroft, Sir Hamo                Sketch for ‘The Mower’
# 14175  Thornycroft, Sir Hamo                  Sketch for ‘Artemis’
# 14176  Thornycroft, Sir Hamo                      Mother and Child
# 14177  Thornycroft, Sir Hamo  Study for the Statue of Cecil Rhodes
#
#                    medium  year  acquisitionYear  width  height units     area
# id
# 14174  Wax on wooden base  1882           1926.0  216.0   121.0    mm  26136.0
# 14175     Plaster and wax  1880           1926.0  184.0    70.0    mm  12880.0
# 14176  Wax on wooden base  1894           1926.0  152.0    83.0    mm  12616.0
# 14177             Plaster  1904           1926.0  248.0    89.0    mm  22072.0
# Tissot, James
#               artist                                              title  \
# id
# 14338  Tissot, James                                           Portrait
# 14339  Tissot, James                        Studies of a Kneeling Woman
# 14340  Tissot, James                       Study of a Girl in a Mob Cap
# 14341  Tissot, James  Study after Reynolds’ Portrait of Mrs Williams...
# 14342  Tissot, James                                           Ramsgate
# 14343  Tissot, James                                            Holyday
#
#                     medium  year  acquisitionYear  width  height units  \
# id
# 14338  Oil paint on canvas  1876           1927.0  914.0   508.0    mm
# 14339    Graphite on paper  1872           1927.0  333.0   489.0    mm
# 14340    Graphite on paper  1872           1927.0  311.0   206.0    mm
# 14341    Graphite on paper  1872           1927.0  121.0    67.0    mm
# 14342         Ink on paper  1876           1927.0  251.0   352.0    mm
# 14343  Oil paint on canvas  1876           1928.0  762.0   994.0    mm
#
#            area
# id
# 14338  464312.0
# 14339  162837.0
# 14340   64066.0
# 14341    8107.0
# 14342   88352.0
# 14343  757428.0
# Troubetzkoy, Paul
#                   artist                title  medium  year  acquisitionYear  \
# id
# 14491  Troubetzkoy, Paul  George Bernard Shaw  Bronze  1926           1927.0
#
#        width  height units      area
# id
# 14491  594.0   365.0    mm  216810.0
# Tryon, Wyndham
#                artist  title        medium  year  acquisitionYear  width  \
# id
# 14494  Tryon, Wyndham  Fraga  Ink on paper  1925           1929.0  314.0
#
#        height units      area
# id
# 14494   464.0    mm  145696.0
# Tuke, Henry Scott
#                   artist                  title             medium  year  \
# id
# 14531  Tuke, Henry Scott  Mrs Florence Humphris  Oil paint on wood  1892
#
#        acquisitionYear  width  height units      area
# id
# 14531           1929.0  400.0   318.0    mm  127200.0
# Turner, Joseph Mallord William
#                                artist  \
# id
# 14913  Turner, Joseph Mallord William
# 14914  Turner, Joseph Mallord William
#
#                                                    title               medium  \
# id
# 14913                      Seascape with Storm Coming On  Oil paint on canvas
# 14914  Venice, the Piazzetta with the Ceremony of the...  Oil paint on canvas
#
#        year  acquisitionYear  width  height units       area
# id
# 14913  1840           1856.0  914.0  1216.0    mm  1111424.0
# 14914  1835           1856.0  914.0  1219.0    mm  1114166.0
# Unwin, Francis
#                artist                                    title  \
# id
# 15673  Unwin, Francis  The Ambulatory, Groote Kerke, Dordrecht
#
#                                   medium  year  acquisitionYear  width  \
# id
# 15673  Graphite and watercolour on paper  1907           1926.0  406.0
#
#        height units      area
# id
# 15673   343.0    mm  139258.0
# Utrillo, Maurice
#                  artist               title               medium  year  \
# id
# 15675  Utrillo, Maurice  La Place du Tertre  Oil paint on canvas  1910
#
#        acquisitionYear  width  height units      area
# id
# 15675           1926.0  502.0   730.0    mm  366460.0
# Vallotton, Félix
#                  artist                  title               medium  year  \
# id
# 15684  Vallotton, Félix  Road at St Paul (Var)  Oil paint on canvas  1922
#
#        acquisitionYear  width  height units      area
# id
# 15684           1927.0  806.0   645.0    mm  519870.0
# Van Aken, Joseph
#                  artist                     title               medium  year  \
# id
# 15689  Van Aken, Joseph  An English Family at Tea  Oil paint on canvas  1720
#
#        acquisitionYear  width  height units       area
# id
# 15689           1930.0  994.0  1162.0    mm  1155028.0
# Varley, John
#              artist                          title                medium  \
# id
# 15706  Varley, John  Near Duncombe Park, Yorkshire  Watercolour on paper
# 15707  Varley, John             Holy Island Castle  Watercolour on paper
#
#        year  acquisitionYear  width  height units     area
# id
# 15706   NaN           1927.0   98.0   127.0    mm  12446.0
# 15707  1810           1927.0  105.0   127.0    mm  13335.0
# Vollon, Antoine
#                 artist                  title               medium  year  \
# id
# 15761  Vollon, Antoine  Harbour at Marseilles  Oil paint on canvas  1882
#
#        acquisitionYear  width  height units      area
# id
# 15761           1926.0  606.0   733.0    mm  444198.0
# Vuillard, Edouard
#                   artist                title              medium  year  \
# id
# 15769  Vuillard, Edouard  Girl in an Interior  Oil paint on board  1910
#
#        acquisitionYear  width  height units      area
# id
# 15769           1929.0  725.0   645.0    mm  467625.0
# Watts, George Frederic
#                        artist                                title  \
# id
# 16023  Watts, George Frederic  Dorothy Tennant, Later Lady Stanley
# 16024  Watts, George Frederic                   Mrs Arthur Sassoon
#
#                     medium  year  acquisitionYear  width  height units  \
# id
# 16023    Oil paint on wood   NaN           1926.0  635.0   533.0    mm
# 16024  Oil paint on canvas  1882           1929.0  660.0   533.0    mm
#
#            area
# id
# 16023  338455.0
# 16024  351780.0
# Wilkie, Sir David
#                   artist                                     title  \
# id
# 16199  Wilkie, Sir David  His Highness Muhemed Ali, Pacha of Egypt
#
#                    medium  year  acquisitionYear  width  height units  \
# id
# 16199  Oil paint on board  1841           1927.0  610.0   508.0    mm
#
#            area
# id
# 16199  309880.0
# Wilson, Richard
#                 artist              title               medium  year  \
# id
# 16239  Wilson, Richard  On Hounslow Heath  Oil paint on canvas  1770
# 16255  Wilson, Richard   Strada Nomentana    Graphite on paper   NaN
#
#        acquisitionYear  width  height units      area
# id
# 16239           1929.0  425.0   527.0    mm  223975.0
# 16255           1930.0  279.0   387.0    mm  107973.0
# Wood, F. Derwent
#                  artist         title  medium  year  acquisitionYear  width  \
# id
# 16452  Wood, F. Derwent  Bess Norriss  Bronze  1921           1926.0  343.0
#
#        height units     area
# id
# 16452   267.0    mm  91581.0
# Wright, Joseph, of Derby
#                          artist               title               medium  \
# id
# 16483  Wright, Joseph, of Derby  Sir Brooke Boothby  Oil paint on canvas
#
#        year  acquisitionYear   width  height units       area
# id
# 16483  1781           1925.0  1486.0  2076.0    mm  3084936.0
# Zoffany, Johan
#                artist             title               medium  year  \
# id
# 16524  Zoffany, Johan  Stephen Rimbault  Oil paint on canvas  1764
#
#        acquisitionYear  width  height units      area
# id
# 16524           1929.0  889.0   711.0    mm  632079.0

# %%
#Aggregate
#Min function
for name,group_df in small_df.groupby("artist"):
    min_year = group_df["acquisitionYear"].min()
    print("{}: {}".format(name, min_year))
    break
# Out:
# ?British School: 1927.0
