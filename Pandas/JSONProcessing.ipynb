# %%
import pandas as pd
import os
import json

# %%
#Define the cols or keys to be used from the json
KEYS_TO_USE = ['id', 'all_artists', 'title', 'medium', 'dateText',
               'acquisitionYear', 'height', 'width', 'units']

# %%
def get_record_from_file(file_path, keys_to_use):
    """ Process single json file and return a tuple
    containing specific fields."""

    with open(file_path) as artwork_file:
        content = json.load(artwork_file)
            
    record = []    
    for field in keys_to_use:
        record.append(content[field])
        
    return tuple(record)

# %%
SAMPLE_JSON="C:\\Users\\sarth\\Documents\\Pandas\\Dataset\\collection-master\\artworks\\a\\000\\a00001-1035.json"

# %%
sample_record = get_record_from_file(SAMPLE_JSON,KEYS_TO_USE)

# %%
sample_record
# Out:
# (1035,
#  'Robert Blake',
#  'A Figure Bowing before a Seated Old Man with his Arm Outstretched in Benediction. Verso: Indecipherable Sketch',
#  'Watercolour, ink, chalk and graphite on paper. Verso: graphite on paper',
#  'date not known',
#  1922,
#  '419',
#  '394',
#  'mm')

# %%
def read_artworks_from_json(keys_to_use):
    """ Traverse the directories with JSON files.
    For first file in each directory call function
    for processing single file and go to the next
    directory.
    """
    JSON_ROOT = "C:\\Users\\sarth\\Documents\\Pandas\\Dataset\\collection-master\\artworks"
    artworks = []
    for root, _, files in os.walk(JSON_ROOT):
        for f in files:
            if f.endswith('json'):
                record = get_record_from_file(
                            os.path.join(root, f),
                            keys_to_use)
                artworks.append(record)
            break
        
    df = pd.DataFrame.from_records(artworks,
                                   columns=keys_to_use,
                                   index="id")
    return df

# %%
df = read_artworks_from_json(KEYS_TO_USE)

# %%
df
# Out:
#                                               all_artists  \
# id
# 1035                                         Robert Blake
# 20230                    Sir Edward Coley Burne-Jones, Bt
# 6725                                 Arthur Boyd Houghton
# 7330                                         George Jones
# 7430                                         George Jones
# 7530                                         George Jones
# 7630                                         George Jones
# 7730                                         George Jones
# 9492                         Sir John Everett Millais, Bt
# 14407                                      Reuben Townroe
# 14700                       Joseph Mallord William Turner
# 12191                                Helen Beatrix Potter
# 69330                                        George Jones
# 69430                                        George Jones
# 69530                                        George Jones
# 69630                                        George Jones
# 69730                                        George Jones
# 69830                                        George Jones
# 98171                                           Alex Katz
# 98537                                        Joseph Beuys
# 97256                                 Robert Mapplethorpe
# 97551                                         Andy Warhol
# 99037                                         Andy Warhol
# 98345                                        Damien Hirst
# 99125                                        Joseph Beuys
# 99132                                        Joseph Beuys
# 105706                                       Joseph Beuys
# 105826                                       Joseph Beuys
# 105944                                       Joseph Beuys
# 106055                                       Joseph Beuys
# ...                                                   ...
# 24928   Lady Wharncliffe (née Lady Caroline Mary Eliza...
# 25315                                  British (?) School
# 25456                                  after John Flaxman
# 25801                                  after John Flaxman
# 25254                                      Abraham Cooper
# 25746                       François Louis Thomas Francia
# 25392                                    John Sell Cotman
# 25713                                  British (?) School
# 25933                                  British (?) School
# 80033                                    Sir Anthony Caro
# 80857                            Richard Parkes Bonington
# 84316                                    Markus Schinwald
# 88228                                        Shoji Hamada
# 88060                             Michelangelo Pistoletto
# 81819                                      Keith Coventry
# 26747                                         Yves Tanguy
# 94662                                              Linder
# 66602                                         Andy Warhol
# 99423                                     William Roberts
# 100499                                    David Batchelor
# 101563                                      Nedko Solakov
# 96968                                       William Blake
# 108923                                       Keith Arnatt
# 90120                                     Prunella Clough
# 111919                        Dominique Gonzalez-Foerster
# 118532                                        Trevor Bell
# 117815                                     Jiro Takamatsu
# 117484                                     Shelagh Cluett
# 89762                                      Robert Mangold
# 123531  Birdhead (Ji Weiyu, born 1980; Song Tao, born ...
#
#                                                     title  \
# id
# 1035    A Figure Bowing before a Seated Old Man with h...
# 20230                          Study of Heads for a Pietà
# 6725                                    [title not known]
# 7330                                    [title not known]
# 7430                                    [title not known]
# 7530                                    [title not known]
# 7630                                    [title not known]
# 7730                                    [title not known]
# 9492                                            The Sower
# 14407                                   [title not known]
# 14700                                  Peat Bog, Scotland
# 12191              The Mice at Work: Threading the Needle
# 69330                                   [title not known]
# 69430                                   [title not known]
# 69530                                   [title not known]
# 69630                                   [title not known]
# 69730                                   [title not known]
# 69830                                   [title not known]
# 98171                                             Pansies
# 98537                                        Weird Sister
# 97256                                      Cock and Devil
# 97551                                           Male Nude
# 99037                                  H.C. Andersen 1987
# 98345       Trinity - Pharmacology, Physiology, Pathology
# 99125                                            Untitled
# 99132                                         Felt Action
# 105706                     Discussion, Documenta 6 Kassel
# 105826     ‘Die zeit der politischen Parteien ist vorbei’
# 105944   Jahre Capital - Kunstkompass Galerie Denise René
# 106055  Joseph Beuys: A Private Collection. Stadthaus ...
# ...                                                   ...
# 24928                                   [title not known]
# 25315          [title not known] Verso: [title not known]
# 25456                                  The Fiery Serpents
# 25801                   Ulysses Giving Wine to Polyphemus
# 25254                                   [title not known]
# 25746                                   [title not known]
# 25392            Tan-y-Bwlch, Merionethshire, North Wales
# 25713                                 Edward Young D.C.L.
# 25933                                   [title not known]
# 80033                                        #73 Untitled
# 80857                         French Coast with Fishermen
# 84316                                          Dictio pii
# 88228                                              Yunomi
# 88060                                   Venus of the Rags
# 81819                                      Heygate Estate
# 26747                                            Untitled
# 94662                                            Untitled
# 66602                                      Brooke Hayward
# 99423                                    The Interruption
# 100499                           Spectrum of Brick Lane 2
# 101563                           A Life (Black and White)
# 96968                              The Book of Thel pl. 6
# 108923                                          Gardeners
# 90120                                               Stack
# 111919                                           Noreturn
# 118532                                              Place
# 117815                                             Shadow
# 117484                                           Flux III
# 89762                                            Red Wall
# 123531                    Welcome to Birdhead World Again
#
#                                                    medium            dateText  \
# id
# 1035    Watercolour, ink, chalk and graphite on paper....      date not known
# 20230                         Graphite and chalk on paper      date not known
# 6725                                    Graphite on paper      date not known
# 7330                                         Ink on paper      date not known
# 7430                                         Ink on paper      date not known
# 7530                                         Ink on paper      date not known
# 7630                                 Watercolour on paper      date not known
# 7730                            Ink and graphite on paper      date not known
# 9492                              Wood engraving on paper      published 1864
# 14407                                Watercolour on paper              c.1858
# 14700                      Etching and engraving on paper                1812
# 12191               Ink, watercolour and gouache on paper              c.1902
# 69330                                Watercolour on paper      date not known
# 69430                                        Ink on paper      date not known
# 69530              Watercolour, ink and graphite on paper      date not known
# 69630                           Ink and graphite on paper      date not known
# 69730                   Watercolour and graphite on paper      date not known
# 69830                   Watercolour and graphite on paper      date not known
# 98171                              Oil paint on hardboard                1967
# 98537                   Graphite and oil paint on acetate             1953–62
# 97256          Photograph, gelatine silver print on paper  1982, printed 1990
# 97551   4 photographs, gelatine silver print on paper ...                1987
# 99037                                Screenprint on paper      date not known
# 98345          Glass, fibreboard, wood, steel and plastic                2000
# 99125         Photograph, gelatine silver print on canvas                1970
# 99132                         Oil paint and felt on paper                1963
# 105706                                     Print on paper                1977
# 105826                                     Print on paper      date not known
# 105944                                     Print on paper                1993
# 106055                                     Print on paper                1991
# ...                                                   ...                 ...
# 24928                                   Graphite on paper      date not known
# 25315   Ink and watercolour on paper. Verso: graphite ...      date not known
# 25456                                    Etching on paper                1807
# 25801                      Engraving and etching on paper                1805
# 25254                                    Etching on paper                1816
# 25746                    Etching and watercolour on paper      date not known
# 25392                                    Etching on paper      date not known
# 25713                                    Etching on paper                1777
# 25933                                    Woodcut on paper      date not known
# 80033            Relief, pencil, chalk, acrylic and paper                1982
# 80857                                 Oil paint on canvas              c.1825
# 84316   Film, 35 mm, shown as video, projection, colou...                2001
# 88228                                   Reduced stoneware              c.1955
# 88060                                 Marble and textiles          1967, 1974
# 81819                 Oil paint on canvas, wood and glass                1995
# 26747                                Watercolour on paper                1937
# 94662                             Printed papers on paper                1976
# 66602          Acrylic paint and silkscreen on 4 canvases                1973
# 99423                                   Graphite on paper             c. 1925
# 100499  Lightboxes, steel shelving, acrylic sheet, flu...                2007
# 101563                              Performance, 2 people                1998
# 96968    Etching with paint, watercolour and ink on paper        1796, c.1818
# 108923          Photograph, gelatin silver print on paper              1978–9
# 90120                                 Oil paint on canvas                1993
# 111919           Video, high definition, colour and sound                2009
# 118532                             Acrylic paint on paper                1989
# 117815                                  Graphite on paper                1965
# 117484      Steel, bitumen, latex, clay and cotton string                1979
# 89762                             Oil paint on fibreboard                1965
# 123531  6 photographs, cellulose print, black and whit...                2011
#
#         acquisitionYear height width units
# id
# 1035               1922    419   394    mm
# 20230              1927    154   136    mm
# 6725               1922
# 7330               1888
# 7430               1888
# 7530               1888
# 7630               1888
# 7730               1888
# 9492               1924    108   140    mm
# 14407              1905
# 14700              1925    258   178    mm
# 12191              1946     92   111    mm
# 69330              1888
# 69430              1888
# 69530              1888
# 69630              1888
# 69730              1888
# 69830              1888
# 98171              2008    404   309    mm
# 98537              2008    474   391    mm
# 97256              2009    472   371    mm
# 97551              2009    540   695    mm
# 99037              2009    599   820    mm
# 98345              2009
# 99125              2009   2275  2330    mm
# 99132              2009    434   647    mm
# 105706             2009    435   609    mm
# 105826             2009    162   273    mm
# 105944             2009    315   679    mm
# 106055             2009    565   808    mm
# ...                 ...    ...   ...   ...
# 24928              1997    157   210    mm
# 25315              1997    149   160    mm
# 25456              1997    192   131    mm
# 25801              1997    247   170    mm
# 25254              1997     76    35    mm
# 25746              1997    255   183    mm
# 25392              1997    171   113    mm
# 25713              1997     66   106    mm
# 25933              1997    191   250    mm
# 80033              2004    630   478    mm
# 80857              2004    967   643    mm
# 84316              2005
# 88228              2005     75    90    mm
# 88060              2006   3400  2120    mm
# 81819              2006    712   966    mm
# 26747              2007    235    80    mm
# 94662              2007
# 66602              2008
# 99423              2008
# 100499             2008    900  5200    mm
# 101563             2009
# 96968              2010    186   260    mm
# 108923             2010    304   404    mm
# 90120              2010   1880  1510    mm
# 111919             2011
# 118532             2012    980   750    mm
# 117815             2012    181   260    mm
# 117484             2012    950  2430    mm
# 89762              2013   2450  2450    mm
# 123531             2013
#
# [738 rows x 8 columns]
